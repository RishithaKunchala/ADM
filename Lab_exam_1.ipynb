# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaKunchala/ADM/blob/main/Lab_exam_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Removing duplicate values
import pandas as pd
data={'Name':['Alice','Bob','Alice','Charlie','Bob'],'Age':[25,30,25,35,30]}
df=pd.DataFrame(data)
df_cleaned=df.drop_duplicates()
print("Dataframe after removing duplicate values: ")
print(df_cleaned)
df.drop_duplicates().plot.bar(x='Name',y='Age',title='Unique Values')
plt.show()
# Out:
# Dataframe after removing duplicate values:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 3  Charlie   35
